# %% [markdown]
# # AutoRA Workflow
#
# Generated by AutoRA Workflow Editor on 2026-08-07T16:23:59.997Z

# %% [markdown]
# ## 1. Install dependencies

# %%
# %pip install autora-core==5.0.3 autora-theorist-darts==1.1.0 autora-synthetic==2.2.0
# Out:
# Requirement already satisfied: autora-core==5.0.3 in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (5.0.3)
# Requirement already satisfied: autora-theorist-darts==1.1.0 in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (1.1.0)
# Requirement already satisfied: autora-synthetic==2.2.0 in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (2.2.0)
# Requirement already satisfied: numpy<2,>=1 in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from autora-core==5.0.3) (1.26.4)
# Requirement already satisfied: matplotlib in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from autora-core==5.0.3) (3.10.9)
# Requirement already satisfied: pandas in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from autora-core==5.0.3) (2.3.3)
# Requirement already satisfied: scikit-learn in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from autora-core==5.0.3) (1.8.0)
# Requirement already satisfied: typer[all] in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from autora-core==5.0.3) (0.26.5)
# Requirement already satisfied: torch in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from autora-theorist-darts==1.1.0) (2.9.1)
# Requirement already satisfied: graphviz in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from autora-theorist-darts==1.1.0) (0.21)
# Requirement already satisfied: tqdm in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from autora-theorist-darts==1.1.0) (4.67.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from matplotlib->autora-core==5.0.3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from matplotlib->autora-core==5.0.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from matplotlib->autora-core==5.0.3) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from matplotlib->autora-core==5.0.3) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from matplotlib->autora-core==5.0.3) (26.2)
# Requirement already satisfied: pillow>=8 in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from matplotlib->autora-core==5.0.3) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from matplotlib->autora-core==5.0.3) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from matplotlib->autora-core==5.0.3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib->autora-core==5.0.3) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from pandas->autora-core==5.0.3) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from pandas->autora-core==5.0.3) (2026.2)
# Requirement already satisfied: scipy>=1.10.0 in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from scikit-learn->autora-core==5.0.3) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from scikit-learn->autora-core==5.0.3) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from scikit-learn->autora-core==5.0.3) (3.6.0)
# Requirement already satisfied: filelock in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from torch->autora-theorist-darts==1.1.0) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from torch->autora-theorist-darts==1.1.0) (4.15.0)
# Requirement already satisfied: setuptools in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from torch->autora-theorist-darts==1.1.0) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from torch->autora-theorist-darts==1.1.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from torch->autora-theorist-darts==1.1.0) (3.6.1)
# Requirement already satisfied: jinja2 in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from torch->autora-theorist-darts==1.1.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from torch->autora-theorist-darts==1.1.0) (2025.12.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from sympy>=1.13.3->torch->autora-theorist-darts==1.1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from jinja2->torch->autora-theorist-darts==1.1.0) (3.0.3)
# WARNING: typer 0.26.5 does not provide the extra 'all'
# Requirement already satisfied: shellingham>=1.3.0 in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from typer[all]->autora-core==5.0.3) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from typer[all]->autora-core==5.0.3) (14.2.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Library/anaconda3/envs/autora/lib/python3.14/site-packages (from typer[all]->autora-core==5.0.3) (0.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 2. Imports

# %%
from autora.state import on_state, Delta, estimator_on_state, StandardState
from autora.variable import VariableCollection, IV, Variable
from autora.experimentalist.random import pool as random_pooler, sample as random_sampler
from autora.experiment_runner.synthetic.abstract.lmm import lmm_experiment
from autora.theorist.darts.regressor import DARTSRegressor

import pandas as pd

# %% [markdown]
# ## 3. Component definitions

# %%
# Random Pooler
@on_state()
def random_pooler_on_state(variables: VariableCollection) -> Delta:
    return Delta(conditions=random_pooler(variables, num_samples=5, replace=True))

# %%
# Random Sampler
@on_state()
def random_sampler_on_state(conditions: pd.DataFrame, num_samples: int = 1) -> Delta:
    return Delta(conditions=random_sampler(conditions=conditions, num_samples=num_samples, replace=False))

# %%
# Linear Mixed Model Experiment (Synthetic, Abstract)
@on_state()
def linear_mixed_model_experiment_on_state(conditions: pd.DataFrame) -> Delta:
    runner = lmm_experiment(formula="rt ~ 1 + x1", fixed_effects={'Intercept': 0., 'x1': 2.},
                           X=[IV(name="x1", value_range=(-5, 5))])
    assert runner.run is not None
    return Delta(experiment_data=runner.run(conditions=conditions))

# %%
# DARTS Regressor
darts_regressor_on_state = estimator_on_state(DARTSRegressor(batch_size=64, num_graph_nodes=2, output_type="real", classifier_weight_decay=0.01, darts_type="original", param_updates_per_epoch=10, param_updates_for_sampled_model=100, param_learning_rate_max=0.025, param_learning_rate_min=0.01, param_momentum=0.9, arch_updates_per_epoch=1, arch_learning_rate_max=0.003, arch_weight_decay=0.0001, arch_weight_decay_df=0.0003, arch_weight_decay_base=0, arch_momentum=0.9, fair_darts_loss_weight=1, max_epochs=10, grad_clip=5, primitives=["none", "add", "subtract", "linear", "linear_logistic", "linear_relu"], train_classifier_coefficients=False, train_classifier_bias=False, sampling_strategy="max"))

# %% [markdown]
# ## 4. Run the workflow

# %%
# Variables are created and governed by the experiment runner
# runner = lmm_experiment(formula="rt ~ 1 + x1", fixed_effects={'Intercept': 0., 'x1': 2.},
#                        X=[IV(name="x1", value_range=(-5, 5))])
# assert runner.variables is not None
# variables = runner.variables

variables = VariableCollection(independent_variables=[Variable(name="x1", value_range=(-5, 5))],
                               dependent_variables=[Variable(name="rt", value_range=(-10, 10))])

# Initialize state
state = StandardState(variables=variables)

# Main experiment loop (1 cycles)
for i in range(1):
    print(f'Cycle {i}')

    # Random Pooler
    state = random_pooler_on_state(state)

    # Random Sampler
    state = random_sampler_on_state(state, num_samples=1)

    # Linear Mixed Model Experiment (Synthetic, Abstract)
    state = linear_mixed_model_experiment_on_state(state)

    # DARTS Regressor
    state = darts_regressor_on_state(state)


print("Workflow completed!")
state
# Out:
# Cycle 0
#   0%|          | 0/10 [00:00<?, ?it/s]
# Cycle 1
# /Library/anaconda3/envs/autora/lib/python3.14/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#   0%|          | 0/10 [00:00<?, ?it/s]
# /Library/anaconda3/envs/autora/lib/python3.14/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Cycle 2
#   0%|          | 0/10 [00:00<?, ?it/s]
# Cycle 3
# /Library/anaconda3/envs/autora/lib/python3.14/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#   0%|          | 0/10 [00:00<?, ?it/s]
# Cycle 4
# /Library/anaconda3/envs/autora/lib/python3.14/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#   0%|          | 0/10 [00:00<?, ?it/s]
# Cycle 5
# /Library/anaconda3/envs/autora/lib/python3.14/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#   0%|          | 0/10 [00:00<?, ?it/s]
# Cycle 6
# /Library/anaconda3/envs/autora/lib/python3.14/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#   0%|          | 0/10 [00:00<?, ?it/s]
# /Library/anaconda3/envs/autora/lib/python3.14/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Cycle 7
#   0%|          | 0/10 [00:00<?, ?it/s]
# Cycle 8
# /Library/anaconda3/envs/autora/lib/python3.14/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#   0%|          | 0/10 [00:00<?, ?it/s]
# Cycle 9
# /Library/anaconda3/envs/autora/lib/python3.14/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#   0%|          | 0/10 [00:00<?, ?it/s]
# Workflow completed!
# /Library/anaconda3/envs/autora/lib/python3.14/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# StandardState(variables=VariableCollection(independent_variables=[Variable(name='x1', value_range=(-5, 5), allowed_values=None, units='', type=<ValueType.REAL: 'real'>, variable_label='', rescale=1, is_covariate=False)], dependent_variables=[Variable(name='rt', value_range=(-10, 10), allowed_values=None, units='', type=<ValueType.REAL: 'real'>, variable_label='', rescale=1, is_covariate=False)], covariates=[]), conditions=         x1
# 0  2.101029, experiment_data=         x1        rt
# 0  3.801789  7.605862
# 1  2.196827  4.386936
# 2  3.958580  7.922362
# 3  0.624173  1.234173
# 4  1.704481  3.398987
# 5  2.332395  4.660745
# 6 -2.787111 -5.590117
# 7 -2.064852 -4.150492
# 8 -2.812580 -5.631649
# 9  2.101029  4.177307, models=[DARTSRegressor(arch_weight_decay_base=0,
#                primitives=['none', 'add', 'subtract', 'linear',
#                            'linear_logistic', 'linear_relu']), DARTSRegressor(arch_weight_decay_base=0,
#                primitives=['none', 'add', 'subtract', 'linear',
#                            'linear_logistic', 'linear_relu']), DARTSRegressor(arch_weight_decay_base=0,
#                primitives=['none', 'add', 'subtract', 'linear',
#                            'linear_logistic', 'linear_relu']), DARTSRegressor(arch_weight_decay_base=0,
#                primitives=['none', 'add', 'subtract', 'linear',
#                            'linear_logistic', 'linear_relu']), DARTSRegressor(arch_weight_decay_base=0,
#                primitives=['none', 'add', 'subtract', 'linear',
#                            'linear_logistic', 'linear_relu']), DARTSRegressor(arch_weight_decay_base=0,
#                primitives=['none', 'add', 'subtract', 'linear',
#                            'linear_logistic', 'linear_relu']), DARTSRegressor(arch_weight_decay_base=0,
#                primitives=['none', 'add', 'subtract', 'linear',
#                            'linear_logistic', 'linear_relu']), DARTSRegressor(arch_weight_decay_base=0,
#                primitives=['none', 'add', 'subtract', 'linear',
#                            'linear_logistic', 'linear_relu']), DARTSRegressor(arch_weight_decay_base=0,
#                primitives=['none', 'add', 'subtract', 'linear',
#                            'linear_logistic', 'linear_relu']), DARTSRegressor(arch_weight_decay_base=0,
#                primitives=['none', 'add', 'subtract', 'linear',
#                            'linear_logistic', 'linear_relu'])])
